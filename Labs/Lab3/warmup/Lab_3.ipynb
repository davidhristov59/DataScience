# %% [markdown]
# # Decision Trees and Gradient Boosting

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# For this laboratory exercise, you will need to install the Anaconda package & environment manager. We will install a minimal distribution, [Miniconda](https://docs.conda.io/projects/miniconda/en/latest/). Choose the adequate distribution for your operating system, download and install it.

# %% [markdown]
# Or use the following commands:
#
# ### Windows
# ```shell
# curl https://repo.anaconda.com/miniconda/Miniconda3-latest-Windows-x86_64.exe -o miniconda.exe
# start /wait "" miniconda.exe /S
# del miniconda.exe
# ```
#
# ### Linux
# ```shell
# mkdir -p ~/miniconda3
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O ~/miniconda3/miniconda.sh
# bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
# rm -rf ~/miniconda3/miniconda.sh
# ```
#
# ### macOS
#
# ```shell
# mkdir -p ~/miniconda3
# curl https://repo.anaconda.com/miniconda/Miniconda3-latest-MacOSX-arm64.sh -o ~/miniconda3/miniconda.sh
# bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
# rm -rf ~/miniconda3/miniconda.sh
# ```
#
# For both Linux and macOS after installing, initialize your newly-installed Miniconda. The following commands initialize for bash and zsh shells:
#
# ```shell
# ~/miniconda3/bin/conda init bash
# ~/miniconda3/bin/conda init zsh
# ```

# %% [markdown]
# Once you have installed miniconda, run the following commands to create an environment:
# ```bash
# conda create --name myenv
# ```
#
# 'myenv' is the name of the environment, you can change the name however you want.
#
# When conda asks you to proceed, type y

# %% [markdown]
# After successfully creating the environment, activate it with the following command:
# ```bash
# conda activate myenv
# ```

# %% [markdown]
# For more detailed information you can read the [documentation](https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html#creating-an-environment-with-commands).

# %% [markdown]
# Now, once the environment is activated, proceed to install the required libraries.
#
# ```bash
# pip install numpy pandas scikit-learn xgboost matplotlib seaborn gdown
# ```

# %% [markdown]
# In the next step, we need to add the environment to jupyter. Use the following commands to install ipykernel and add the environment to ipykernel.
#
# ```bash
# pip install ipykernel
# ```
# ```bash
# python -m ipykernel install --name=myenv
# ```

# %% [markdown]
# Next, start Jupyter Notebook, download this starter notebook and open it. On the dropdown menu in the Kernel tab choose the name of the environment you created, like in the picture below.

# %% [markdown]
# ![jupyter](https://drive.google.com/uc?export=view&id=1N-27jjlIgpTILi-_6lny7ng8sE52SAZx)

# %% [markdown]
# ## Download and Read the Dataset

# %% [markdown]
# run the code below for downloading the dataset

# %%
# !gdown 1boIax8d9Sat6OJzkiIjjpqmtSZKuRYrx
# Out:
# Error:
#
# 	HTTPSConnectionPool(host='doc-14-1k-docs.googleusercontent.com',
# 	port=443): Max retries exceeded with url: /docs/securesc/ha0ro937gcuc7
# 	l7deffksulhg5h7mbp1/h198dtpgsnbqh9b4o0ae3ast6tg3d8vh/1735238775000/040
# 	43802626059007351/*/1boIax8d9Sat6OJzkiIjjpqmtSZKuRYrx?uuid=a8d4f1f2-
# 	ed14-431a-aa7a-b6a2c48ee32e (Caused by
# 	NameResolutionError("<urllib3.connection.HTTPSConnection object at
# 	0x1072f1700>: Failed to resolve 'doc-14-1k-docs.googleusercontent.com'
# 	([Errno 8] nodename nor servname provided, or not known)"))
#
# To report issues, please visit https://github.com/wkentaro/gdown/issues.

# %%
# !pip install numpy pandas scikit-learn xgboost matplotlib seaborn gdown
# Out:
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (1.4.2)
# Requirement already satisfied: xgboost in /opt/anaconda3/lib/python3.12/site-packages (2.1.3)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: seaborn in /opt/anaconda3/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: gdown in /opt/anaconda3/lib/python3.12/site-packages (5.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.12/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /opt/anaconda3/lib/python3.12/site-packages (from gdown) (2.32.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from gdown) (4.66.4)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests[socks]->gdown) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests[socks]->gdown) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from requests[socks]->gdown) (1.7.1)

# %% [markdown]
# ### Import the required libraries

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor 
import numpy as np
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from xgboost import XGBRegressor

# %% [markdown]
# ### Read the dataset

# %% [markdown]
# CONTEXT:
# This is a dataset of electric vehicles.
#
# It contains the following columns:
#
#
# *   Brand
# *   Model
# *   AccelSec - Acceleration as 0-100 km/h
# *   TopSpeed_KmH - The top speed in km/h
# *   Range_Km - Range in km
# *   Efficiency_WhKm - Efficiency Wh/km
# *   FastCharge_KmH - Charge km/h
# *   RapidCharge - Yes / No
# *   PowerTrain - Front, rear, or all wheel drive
# *   PlugType
# *   BodyStyle - Basic size or style
# *   Segment - Market segment
# *   Seats - Number of seats
# *   PriceEuro - Price in Germany before tax incentives

# %% [markdown]
# TASK:
# Predict the target 'PriceEuro' and compare the performance of the DecisionTreeRegressor and the XGBRegressor models.

# %%
data = pd.read_csv('ElectricCarData.csv')

# %%
data.head()
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# 1  Type 2 CCS  Hatchback       C      5      30000
# 2  Type 2 CCS   Liftback       D      5      56440
# 3  Type 2 CCS        SUV       D      5      68040
# 4  Type 2 CCS  Hatchback       B      4      32997

# %%
data.isnull().sum()
# Out:
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              0
# PriceEuro          0
# dtype: int64

# %%
data.head(30)
# Out:
#           Brand                           Model  AccelSec  TopSpeed_KmH  \
# 0        Tesla    Model 3 Long Range Dual Motor       4.6           233
# 1   Volkswagen                        ID.3 Pure      10.0           160
# 2     Polestar                                2       4.7           210
# 3          BMW                             iX3        6.8           180
# 4        Honda                               e        9.5           145
# 5        Lucid                             Air        2.8           250
# 6   Volkswagen                          e-Golf        9.6           150
# 7      Peugeot                           e-208        8.1           150
# 8        Tesla      Model 3 Standard Range Plus       5.6           225
# 9         Audi                       Q4 e-tron        6.3           180
# 10    Mercedes                   EQC 400 4MATIC       5.1           180
# 11      Nissan                            Leaf        7.9           144
# 12     Hyundai             Kona Electric 64 kWh       7.9           167
# 13         BMW                              i4        4.0           200
# 14     Hyundai                   IONIQ Electric       9.7           165
# 15  Volkswagen                       ID.3 Pro S       7.9           160
# 16     Porsche                   Taycan Turbo S       2.8           260
# 17  Volkswagen                           e-Up!       11.9           130
# 18          MG                            ZS EV       8.2           140
# 19        Mini                       Cooper SE        7.3           150
# 20        Opel                         Corsa-e        8.1           150
# 21       Tesla    Model Y Long Range Dual Motor       5.1           217
# 22       Skoda                      Enyaq iV 50      10.0           160
# 23        Audi                       e-tron GT        3.5           240
# 24       Tesla   Model 3 Long Range Performance       3.4           261
# 25  Volkswagen                            ID.4        7.5           160
# 26  Volkswagen                         ID.3 Pro       9.0           160
# 27       Volvo             XC40 P8 AWD Recharge       4.9           180
# 28         BMW                        i3 120 Ah       7.3           150
# 29     Peugeot                      e-2008 SUV        8.5           150
#
#     Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0        450              161            940         Yes        AWD
# 1        270              167            250         Yes        RWD
# 2        400              181            620         Yes        AWD
# 3        360              206            560         Yes        RWD
# 4        170              168            190         Yes        RWD
# 5        610              180            620         Yes        AWD
# 6        190              168            220         Yes        FWD
# 7        275              164            420         Yes        FWD
# 8        310              153            650         Yes        RWD
# 9        400              193            540         Yes        AWD
# 10       370              216            440         Yes        AWD
# 11       220              164            230         Yes        FWD
# 12       400              160            380         Yes        FWD
# 13       450              178            650         Yes        RWD
# 14       250              153            210         Yes        FWD
# 15       440              175            590         Yes        RWD
# 16       375              223            780         Yes        AWD
# 17       195              166            170         Yes        FWD
# 18       220              193            260         Yes        FWD
# 19       185              156            260         Yes        FWD
# 20       275              164            420         Yes        FWD
# 21       425              171            930         Yes        AWD
# 22       290              179            230         Yes        RWD
# 23       425              197            850         Yes        AWD
# 24       435              167            910         Yes        AWD
# 25       420              183            560         Yes        RWD
# 26       350              166            490         Yes        RWD
# 27       375              200            470         Yes        AWD
# 28       235              161            270         Yes        RWD
# 29       250              180            380         Yes        FWD
#
#           PlugType  BodyStyle Segment  Seats  PriceEuro
# 0       Type 2 CCS      Sedan       D      5      55480
# 1       Type 2 CCS  Hatchback       C      5      30000
# 2       Type 2 CCS   Liftback       D      5      56440
# 3       Type 2 CCS        SUV       D      5      68040
# 4       Type 2 CCS  Hatchback       B      4      32997
# 5       Type 2 CCS      Sedan       F      5     105000
# 6       Type 2 CCS  Hatchback       C      5      31900
# 7       Type 2 CCS  Hatchback       B      5      29682
# 8       Type 2 CCS      Sedan       D      5      46380
# 9       Type 2 CCS        SUV       D      5      55000
# 10      Type 2 CCS        SUV       D      5      69484
# 11  Type 2 CHAdeMO  Hatchback       C      5      29234
# 12      Type 2 CCS        SUV       B      5      40795
# 13      Type 2 CCS      Sedan       D      5      65000
# 14      Type 2 CCS   Liftback       C      5      34459
# 15      Type 2 CCS  Hatchback       C      4      40936
# 16      Type 2 CCS      Sedan       F      4     180781
# 17      Type 2 CCS  Hatchback       A      4      21421
# 18      Type 2 CCS        SUV       B      5      30000
# 19      Type 2 CCS  Hatchback       B      4      31681
# 20      Type 2 CCS  Hatchback       B      5      29146
# 21      Type 2 CCS        SUV       D      7      58620
# 22      Type 2 CCS        SUV       C      5      35000
# 23      Type 2 CCS      Sedan       F      4     125000
# 24      Type 2 CCS      Sedan       D      5      61480
# 25      Type 2 CCS        SUV       C      5      45000
# 26      Type 2 CCS  Hatchback       C      5      33000
# 27      Type 2 CCS        SUV       C      5      60437
# 28      Type 2 CCS  Hatchback       B      4      38017
# 29      Type 2 CCS        SUV       B      5      34361

# %%
data = data.drop(columns='Model')

# %%
data
# Out:
#            Brand  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm  \
# 0         Tesla        4.6           233       450              161
# 1    Volkswagen       10.0           160       270              167
# 2      Polestar        4.7           210       400              181
# 3           BMW        6.8           180       360              206
# 4         Honda        9.5           145       170              168
# ..           ...       ...           ...       ...              ...
# 98       Nissan        7.5           160       330              191
# 99         Audi        4.5           210       335              258
# 100      Nissan        5.9           200       325              194
# 101      Nissan        5.1           200       375              232
# 102       Byton        7.5           190       400              238
#
#     FastCharge_KmH RapidCharge PowerTrain    PlugType  BodyStyle Segment  \
# 0              940         Yes        AWD  Type 2 CCS      Sedan       D
# 1              250         Yes        RWD  Type 2 CCS  Hatchback       C
# 2              620         Yes        AWD  Type 2 CCS   Liftback       D
# 3              560         Yes        RWD  Type 2 CCS        SUV       D
# 4              190         Yes        RWD  Type 2 CCS  Hatchback       B
# ..             ...         ...        ...         ...        ...     ...
# 98             440         Yes        FWD  Type 2 CCS  Hatchback       C
# 99             540         Yes        AWD  Type 2 CCS        SUV       E
# 100            440         Yes        AWD  Type 2 CCS  Hatchback       C
# 101            450         Yes        AWD  Type 2 CCS  Hatchback       C
# 102            480         Yes        AWD  Type 2 CCS        SUV       E
#
#      Seats  PriceEuro
# 0        5      55480
# 1        5      30000
# 2        5      56440
# 3        5      68040
# 4        4      32997
# ..     ...        ...
# 98       5      45000
# 99       5      96050
# 100      5      50000
# 101      5      65000
# 102      5      62000
#
# [103 rows x 13 columns]

# %%
data['FastCharge_KmH'].unique()
# Out:
# array(['940', '250', '620', '560', '190', '220', '420', '650', '540',
#        '440', '230', '380', '210', '590', '780', '170', '260', '930',
#        '850', '910', '490', '470', '270', '450', '350', '710', '240',
#        '390', '570', '610', '340', '730', '920', '-', '550', '900', '520',
#        '430', '890', '410', '770', '460', '360', '810', '480', '290',
#        '330', '740', '510', '320', '500'], dtype=object)

# %%
data.replace('-', np.nan, inplace=True)

# %%
data.fillna(data.mean(numeric_only=True), inplace=True)

# %%
data.isnull().sum()
# Out:
# Brand              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     5
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              0
# PriceEuro          0
# dtype: int64

# %% [markdown]
# ### Encode string variables

# %%
data = pd.get_dummies(data, columns = ['PlugType', 'Segment', 'PowerTrain'], prefix=['PlugType', 'Segment', 'PowerTrain']) # so one-hot encoding

# %%
encoder = LabelEncoder()

data['Brand'] = encoder.fit_transform(data['Brand'])
data['BodyStyle'] = encoder.fit_transform(data['BodyStyle'])
data['RapidCharge'] = encoder.fit_transform(data['RapidCharge'])

# %%
data
# Out:
#      Brand  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm FastCharge_KmH  \
# 0       30       4.6           233       450              161            940
# 1       31      10.0           160       270              167            250
# 2       23       4.7           210       400              181            620
# 3        2       6.8           180       360              206            560
# 4        9       9.5           145       170              168            190
# ..     ...       ...           ...       ...              ...            ...
# 98      20       7.5           160       330              191            440
# 99       1       4.5           210       335              258            540
# 100     20       5.9           200       325              194            440
# 101     20       5.1           200       375              232            450
# 102      3       7.5           190       400              238            480
#
#      RapidCharge  BodyStyle  Seats  PriceEuro  ...  Segment_B  Segment_C  \
# 0              1          7      5      55480  ...      False      False
# 1              1          1      5      30000  ...      False       True
# 2              1          2      5      56440  ...      False      False
# 3              1          6      5      68040  ...      False      False
# 4              1          1      4      32997  ...       True      False
# ..           ...        ...    ...        ...  ...        ...        ...
# 98             1          1      5      45000  ...      False       True
# 99             1          6      5      96050  ...      False      False
# 100            1          1      5      50000  ...      False       True
# 101            1          1      5      65000  ...      False       True
# 102            1          6      5      62000  ...      False      False
#
#      Segment_D  Segment_E  Segment_F  Segment_N  Segment_S  PowerTrain_AWD  \
# 0         True      False      False      False      False            True
# 1        False      False      False      False      False           False
# 2         True      False      False      False      False            True
# 3         True      False      False      False      False           False
# 4        False      False      False      False      False           False
# ..         ...        ...        ...        ...        ...             ...
# 98       False      False      False      False      False           False
# 99       False       True      False      False      False            True
# 100      False      False      False      False      False            True
# 101      False      False      False      False      False            True
# 102      False       True      False      False      False            True
#
#      PowerTrain_FWD  PowerTrain_RWD
# 0             False           False
# 1             False            True
# 2             False           False
# 3             False            True
# 4             False            True
# ..              ...             ...
# 98             True           False
# 99            False           False
# 100           False           False
# 101           False           False
# 102           False           False
#
# [103 rows x 25 columns]

# %% [markdown]
# ## Split the dataset for training and testing in ratio 80:20

# %%
x = data.drop(columns='PriceEuro')
y = data['PriceEuro']

# %%
x
# Out:
#      Brand  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm FastCharge_KmH  \
# 0       30       4.6           233       450              161            940
# 1       31      10.0           160       270              167            250
# 2       23       4.7           210       400              181            620
# 3        2       6.8           180       360              206            560
# 4        9       9.5           145       170              168            190
# ..     ...       ...           ...       ...              ...            ...
# 98      20       7.5           160       330              191            440
# 99       1       4.5           210       335              258            540
# 100     20       5.9           200       325              194            440
# 101     20       5.1           200       375              232            450
# 102      3       7.5           190       400              238            480
#
#      RapidCharge  BodyStyle  Seats  PlugType_Type 1 CHAdeMO  ...  Segment_B  \
# 0              1          7      5                    False  ...      False
# 1              1          1      5                    False  ...      False
# 2              1          2      5                    False  ...      False
# 3              1          6      5                    False  ...      False
# 4              1          1      4                    False  ...       True
# ..           ...        ...    ...                      ...  ...        ...
# 98             1          1      5                    False  ...      False
# 99             1          6      5                    False  ...      False
# 100            1          1      5                    False  ...      False
# 101            1          1      5                    False  ...      False
# 102            1          6      5                    False  ...      False
#
#      Segment_C  Segment_D  Segment_E  Segment_F  Segment_N  Segment_S  \
# 0        False       True      False      False      False      False
# 1         True      False      False      False      False      False
# 2        False       True      False      False      False      False
# 3        False       True      False      False      False      False
# 4        False      False      False      False      False      False
# ..         ...        ...        ...        ...        ...        ...
# 98        True      False      False      False      False      False
# 99       False      False       True      False      False      False
# 100       True      False      False      False      False      False
# 101       True      False      False      False      False      False
# 102      False      False       True      False      False      False
#
#      PowerTrain_AWD  PowerTrain_FWD  PowerTrain_RWD
# 0              True           False           False
# 1             False           False            True
# 2              True           False           False
# 3             False           False            True
# 4             False           False            True
# ..              ...             ...             ...
# 98            False            True           False
# 99             True           False           False
# 100            True           False           False
# 101            True           False           False
# 102            True           False           False
#
# [103 rows x 24 columns]

# %%
y
# Out:
# 0      55480
# 1      30000
# 2      56440
# 3      68040
# 4      32997
#        ...
# 98     45000
# 99     96050
# 100    50000
# 101    65000
# 102    62000
# Name: PriceEuro, Length: 103, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ## Initialize the DecisionTreeRegressor model, and use the fit function for training the model.
#
# Add values for the parameters max_depth, min_samples_split, and max_features.

# %% [markdown]
# Fit the model using the fit function

# %%
data['FastCharge_KmH'].unique()
# Out:
# array(['940', '250', '620', '560', '190', '220', '420', '650', '540',
#        '440', '230', '380', '210', '590', '780', '170', '260', '930',
#        '850', '910', '490', '470', '270', '450', '350', '710', '240',
#        '390', '570', '610', '340', '730', '920', nan, '550', '900', '520',
#        '430', '890', '410', '770', '460', '360', '810', '480', '290',
#        '330', '740', '510', '320', '500'], dtype=object)

# %%
for column in x_train.columns:
    if x_train[column].dtype == 'object':  # Check for non-numeric columns
        print(column, x_train[column].unique())
# Out:
# FastCharge_KmH ['710' '450' '380' '480' nan '810' '260' '350' '560' '170' '520' '890'
#  '240' '210' '290' '340' '730' '360' '230' '850' '470' '610' '330' '220'
#  '190' '440' '320' '920' '490' '430' '770' '590' '650' '740' '420' '540'
#  '550' '270' '390' '940' '510' '620' '910' '250' '500' '900']

# %%
x_train.replace('-', np.nan, inplace=True)

# %%
data.isnull().sum()
# Out:
# Brand                      0
# AccelSec                   0
# TopSpeed_KmH               0
# Range_Km                   0
# Efficiency_WhKm            0
# FastCharge_KmH             5
# RapidCharge                0
# BodyStyle                  0
# Seats                      0
# PriceEuro                  0
# PlugType_Type 1 CHAdeMO    0
# PlugType_Type 2            0
# PlugType_Type 2 CCS        0
# PlugType_Type 2 CHAdeMO    0
# Segment_A                  0
# Segment_B                  0
# Segment_C                  0
# Segment_D                  0
# Segment_E                  0
# Segment_F                  0
# Segment_N                  0
# Segment_S                  0
# PowerTrain_AWD             0
# PowerTrain_FWD             0
# PowerTrain_RWD             0
# dtype: int64

# %%
model = DecisionTreeRegressor(max_depth=5, min_samples_split=3, max_features='sqrt')

model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, max_features='sqrt', min_samples_split=3)

# %% [markdown]
# ## Predict the outcomes for X test

# %%
x_test
# Out:
#      Brand  AccelSec  TopSpeed_KmH  Range_Km  Efficiency_WhKm FastCharge_KmH  \
# 21      30       5.1           217       425              171            930
# 44      26      12.3           130       195              166            170
# 102      3       7.5           190       400              238            480
# 69       8       6.0           180       430              209            410
# 80      31       7.3           160       340              171            470
# 41      10       9.9           155       255              154            210
# 73       3       5.5           190       390              244            460
# 9        1       6.3           180       400              193            540
# 46      21       7.3           150       335              173            210
# 35      20       7.3           157       325              172            390
# 88      27       6.2           180       400              193            540
# 48      14      10.0           150       575              104            540
# 16      24       2.8           260       375              223            780
# 58       5       9.7           150       250              180            380
# 37       4       6.5           160       425              181            570
# 98      20       7.5           160       330              191            440
# 5       15       2.8           250       610              180            620
# 91      28      11.9           130        95              176            NaN
# 12      10       7.9           167       400              160            380
# 57      25      12.6           135       130              164            NaN
# 82      28      11.6           130       100              167            NaN
#
#      RapidCharge  BodyStyle  Seats  PlugType_Type 1 CHAdeMO  ...  Segment_B  \
# 21             1          6      7                    False  ...      False
# 44             1          1      4                    False  ...      False
# 102            1          6      5                    False  ...      False
# 69             1          6      5                    False  ...      False
# 80             1          1      5                    False  ...      False
# 41             1          6      5                    False  ...       True
# 73             1          6      5                    False  ...      False
# 9              1          6      5                    False  ...      False
# 46             1          3      5                    False  ...       True
# 35             1          1      5                    False  ...      False
# 88             1          6      5                    False  ...      False
# 48             1          2      5                    False  ...      False
# 16             1          7      4                    False  ...      False
# 58             1          6      5                    False  ...      False
# 37             1          1      4                    False  ...      False
# 98             1          1      5                    False  ...      False
# 5              1          7      5                    False  ...      False
# 91             0          0      2                    False  ...      False
# 12             1          6      5                    False  ...       True
# 57             0          1      4                    False  ...      False
# 82             0          1      2                    False  ...      False
#
#      Segment_C  Segment_D  Segment_E  Segment_F  Segment_N  Segment_S  \
# 21       False       True      False      False      False      False
# 44       False      False      False      False      False      False
# 102      False      False       True      False      False      False
# 69       False       True      False      False      False      False
# 80        True      False      False      False      False      False
# 41       False      False      False      False      False      False
# 73       False      False       True      False      False      False
# 9        False       True      False      False      False      False
# 46       False      False      False      False      False      False
# 35        True      False      False      False      False      False
# 88        True      False      False      False      False      False
# 48       False      False      False       True      False      False
# 16       False      False      False       True      False      False
# 58        True      False      False      False      False      False
# 37        True      False      False      False      False      False
# 98        True      False      False      False      False      False
# 5        False      False      False       True      False      False
# 91       False      False      False      False      False      False
# 12       False      False      False      False      False      False
# 57       False      False      False      False      False      False
# 82       False      False      False      False      False      False
#
#      PowerTrain_AWD  PowerTrain_FWD  PowerTrain_RWD
# 21             True           False           False
# 44            False            True           False
# 102            True           False           False
# 69             True           False           False
# 80            False           False            True
# 41            False            True           False
# 73             True           False           False
# 9              True           False           False
# 46            False            True           False
# 35            False            True           False
# 88             True           False           False
# 48             True           False           False
# 16             True           False           False
# 58            False            True           False
# 37            False           False            True
# 98            False            True           False
# 5              True           False           False
# 91            False           False            True
# 12            False            True           False
# 57            False           False            True
# 82            False           False            True
#
# [21 rows x 24 columns]

# %%
data['FastCharge_KmH'].unique()
# Out:
# array(['940', '250', '620', '560', '190', '220', '420', '650', '540',
#        '440', '230', '380', '210', '590', '780', '170', '260', '930',
#        '850', '910', '490', '470', '270', '450', '350', '710', '240',
#        '390', '570', '610', '340', '730', '920', nan, '550', '900', '520',
#        '430', '890', '410', '770', '460', '360', '810', '480', '290',
#        '330', '740', '510', '320', '500'], dtype=object)

# %%
x_test = x_test.replace('-', np.nan)

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([ 62250.66666667,  22977.5       ,  72741.63157895,  54549.16666667,
#         39397.22222222,  32725.65      ,  72741.63157895,  54549.16666667,
#         32725.65      ,  32725.65      ,  72741.63157895,  72741.63157895,
#        149150.5       ,  32725.65      ,  37879.4       ,  36559.5       ,
#         72741.63157895,  22030.        ,  36559.5       ,  22030.        ,
#         22030.        ])

# %% [markdown]
# ## Assess the model performance, by using sklearn metrics for regression

# %%
print(r2_score(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.7272285852061902
# 11833.77081592871
# 432867232.64086515

# %% [markdown]
# ## Initialize the XGBRegressor model, and use the fit function

# %% [markdown]
# Add values for the parameters: n_estimators, max_depth, learning_rate, and set the objective to "reg:squarederror"

# %% [markdown]
# Fit the model using the fit function

# %%
model2 = XGBRegressor(n_estimators = 50, max_depth = 5, learning_rate = 0.2, objective ='reg:squarederror')

model2.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 3
#       1 model2 = XGBRegressor(n_estimators = 50, max_depth = 5, learning_rate = 0.2, objective ='reg:squarederror')
# ----> 3 model2.fit(x_train, y_train)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/sklearn.py:1081, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1079 with config_context(verbosity=self.verbosity):
#    1080     evals_result: TrainingCallback.EvalsLog = {}
# -> 1081     train_dmatrix, evals = _wrap_evaluation_matrices(
#    1082         missing=self.missing,
#    1083         X=X,
#    1084         y=y,
#    1085         group=None,
#    1086         qid=None,
#    1087         sample_weight=sample_weight,
#    1088         base_margin=base_margin,
#    1089         feature_weights=feature_weights,
#    1090         eval_set=eval_set,
#    1091         sample_weight_eval_set=sample_weight_eval_set,
#    1092         base_margin_eval_set=base_margin_eval_set,
#    1093         eval_group=None,
#    1094         eval_qid=None,
#    1095         create_dmatrix=self._create_dmatrix,
#    1096         enable_categorical=self.enable_categorical,
#    1097         feature_types=self.feature_types,
#    1098     )
#    1099     params = self.get_xgb_params()
#    1101     if callable(self.objective):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/sklearn.py:596, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     576 def _wrap_evaluation_matrices(
#     577     missing: float,
#     578     X: Any,
#    (...)
#     592     feature_types: Optional[FeatureTypes],
#     593 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     594     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     595     way."""
# --> 596     train_dmatrix = create_dmatrix(
#     597         data=X,
#     598         label=y,
#     599         group=group,
#     600         qid=qid,
#     601         weight=sample_weight,
#     602         base_margin=base_margin,
#     603         feature_weights=feature_weights,
#     604         missing=missing,
#     605         enable_categorical=enable_categorical,
#     606         feature_types=feature_types,
#     607         ref=None,
#     608     )
#     610     n_validation = 0 if eval_set is None else len(eval_set)
#     612     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/sklearn.py:1003, in XGBModel._create_dmatrix(self, ref, **kwargs)
#    1001 if _can_use_qdm(self.tree_method) and self.booster != "gblinear":
#    1002     try:
# -> 1003         return QuantileDMatrix(
#    1004             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#    1005         )
#    1006     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#    1007         pass
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:1573, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, data_split_mode)
#    1553     if any(
#    1554         info is not None
#    1555         for info in (
#    (...)
#    1566         )
#    1567     ):
#    1568         raise ValueError(
#    1569             "If data iterator is used as input, data like label should be "
#    1570             "specified as batch argument."
#    1571         )
# -> 1573 self._init(
#    1574     data,
#    1575     ref=ref,
#    1576     label=label,
#    1577     weight=weight,
#    1578     base_margin=base_margin,
#    1579     group=group,
#    1580     qid=qid,
#    1581     label_lower_bound=label_lower_bound,
#    1582     label_upper_bound=label_upper_bound,
#    1583     feature_weights=feature_weights,
#    1584     feature_names=feature_names,
#    1585     feature_types=feature_types,
#    1586     enable_categorical=enable_categorical,
#    1587 )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:1632, in QuantileDMatrix._init(self, data, ref, enable_categorical, **meta)
#    1620 config = make_jcargs(
#    1621     nthread=self.nthread, missing=self.missing, max_bin=self.max_bin
#    1622 )
#    1623 ret = _LIB.XGQuantileDMatrixCreateFromCallback(
#    1624     None,
#    1625     it.proxy.handle,
#    (...)
#    1630     ctypes.byref(handle),
#    1631 )
# -> 1632 it.reraise()
#    1633 # delay check_call to throw intermediate exception first
#    1634 _check_call(ret)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:569, in DataIter.reraise(self)
#     567 exc = self._exception
#     568 self._exception = None
# --> 569 raise exc
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:550, in DataIter._handle_exception(self, fn, dft_ret)
#     547     return dft_ret
#     549 try:
# --> 550     return fn()
#     551 except Exception as e:  # pylint: disable=broad-except
#     552     # Defer the exception in order to return 0 and stop the iteration.
#     553     # Exception inside a ctype callback function has no effect except
#     554     # for printing to stderr (doesn't stop the execution).
#     555     tb = sys.exc_info()[2]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:637, in DataIter._next_wrapper.<locals>.<lambda>()
#     635     self._temporary_data = None
#     636 # pylint: disable=not-callable
# --> 637 return self._handle_exception(lambda: self.next(input_data), 0)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/data.py:1402, in SingleBatchInternalIter.next(self, input_data)
#    1400     return 0
#    1401 self.it += 1
# -> 1402 input_data(**self.kwargs)
#    1403 return 1
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/core.py:617, in DataIter._next_wrapper.<locals>.input_data(data, feature_names, feature_types, **kwargs)
#     615     new, cat_codes, feature_names, feature_types = self._temporary_data
#     616 else:
# --> 617     new, cat_codes, feature_names, feature_types = _proxy_transform(
#     618         data,
#     619         feature_names,
#     620         feature_types,
#     621         self._enable_categorical,
#     622     )
#     623 # Stage the data, meta info are copied inside C++ MetaInfo.
#     624 self._temporary_data = (new, cat_codes, feature_names, feature_types)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/data.py:1447, in _proxy_transform(data, feature_names, feature_types, enable_categorical)
#    1445     data = _arrow_transform(data)
#    1446 if _is_pandas_df(data):
# -> 1447     df, feature_names, feature_types = _transform_pandas_df(
#    1448         data, enable_categorical, feature_names, feature_types
#    1449     )
#    1450     return df, None, feature_names, feature_types
#    1451 raise TypeError("Value type is not supported for data iterator:" + str(type(data)))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/data.py:603, in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta)
#     596 def _transform_pandas_df(
#     597     data: DataFrame,
#     598     enable_categorical: bool,
#    (...)
#     601     meta: Optional[str] = None,
#     602 ) -> Tuple[PandasTransformed, Optional[FeatureNames], Optional[FeatureTypes]]:
# --> 603     pandas_check_dtypes(data, enable_categorical)
#     604     if meta and len(data.columns) > 1 and meta not in _matrix_meta:
#     605         raise ValueError(f"DataFrame for {meta} cannot have multiple columns")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/data.py:569, in pandas_check_dtypes(data, enable_categorical)
#     562 for dtype in data.dtypes:
#     563     if not (
#     564         (dtype.name in _pandas_dtype_mapper)
#     565         or is_pd_sparse_dtype(dtype)
#     566         or (is_pd_cat_dtype(dtype) and enable_categorical)
#     567         or is_pa_ext_dtype(dtype)
#     568     ):
# --> 569         _invalid_dataframe_dtype(data)
#     571     if is_pd_sparse_dtype(dtype):
#     572         sparse_extension = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/data.py:356, in _invalid_dataframe_dtype(data)
#     354 type_err = "DataFrame.dtypes for data must be int, float, bool or category."
#     355 msg = f"""{type_err} {_ENABLE_CAT_ERR} {err}"""
# --> 356 raise ValueError(msg)
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or category. When categorical type is supplied, the experimental DMatrix parameter`enable_categorical` must be set to `True`.  Invalid columns:FastCharge_KmH: object

# %% [markdown]
# ## Predict the outcomes for X test

# %%
y_pred2 = model2.predict(x_test)

# %%
y_pred2
# Out:
# array([ 54992.402,  75573.93 ,  72279.77 ,  36651.676,  55892.703,
#         39745.223, 104804.41 ,  33551.652,  40984.414,  53505.477,
#         95938.78 ,  65654.56 ,  49289.402,  33901.125,  32431.36 ,
#         45243.836,  54475.883,  74741.99 ,  23598.312,  30871.182,
#         30608.709], dtype=float32)

# %% [markdown]
# ## Assess the model performance, by using sklearn metrics for regression

# %%
print(r2_score(y_test, y_pred2))
print(mean_absolute_error(y_test, y_pred2))
print(mean_squared_error(y_test, y_pred2))
# Out:
# 0.9101185764354356
# 4510.181919642857
# 44073881.31966836

# %% [markdown]
# ## Compare the performances of both model for at least three regression metircs
